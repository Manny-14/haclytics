# %% [markdown]
# ## Objective
# Build a predictive model that estimatest he probability of various match outcomes (win, draw, loss) for each team.
#
# ### Application
# To be used in a sports betting scenario by comparing model's predicted probabilities with betting odds, I can potentially spot value bets

# %%
# libraries
# %pip install scikit-learn
import pandas as pd
from sklearn.preprocessing import StandardScaler
# Out:
# Requirement already satisfied: scikit-learn in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (from scikit-learn) (2.2.3)
# Requirement already satisfied: scipy>=1.6.0 in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_parquet('games.parquet')
print(df.head())
# Out:
#                       home                  away        date  gh  ga  \
# 0         Bolton Wanderers          Derby County  1888-09-08   3   6
# 1               Everton FC         Accrington FC  1888-09-08   2   1
# 2        Preston North End            Burnley FC  1888-09-08   5   2
# 3               Stoke City  West Bromwich Albion  1888-09-08   0   2
# 4  Wolverhampton Wanderers           Aston Villa  1888-09-08   1   1
#
#   full_time competition                         home_ident  \
# 0         F     england         Bolton Wanderers (England)
# 1         F     england               Everton FC (England)
# 2         F     england        Preston North End (England)
# 3         F     england               Stoke City (England)
# 4         F     england  Wolverhampton Wanderers (England)
#
#                        away_ident home_country away_country home_code  \
# 0          Derby County (England)      england      england       ENG
# 1         Accrington FC (England)      england      england       ENG
# 2            Burnley FC (England)      england      england       ENG
# 3  West Bromwich Albion (England)      england      england       ENG
# 4           Aston Villa (England)      england      england       ENG
#
#   away_code home_continent away_continent continent     level
# 0       ENG         Europe         Europe    Europe  national
# 1       ENG         Europe         Europe    Europe  national
# 2       ENG         Europe         Europe    Europe  national
# 3       ENG         Europe         Europe    Europe  national
# 4       ENG         Europe         Europe    Europe  national

# %%
# More examindation of the data
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1237935 entries, 0 to 1237934
# Data columns (total 17 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   home            1237575 non-null  object
#  1   away            1237568 non-null  object
#  2   date            1237935 non-null  object
#  3   gh              1237935 non-null  int32
#  4   ga              1237935 non-null  int32
#  5   full_time       1237935 non-null  object
#  6   competition     1229433 non-null  object
#  7   home_ident      1237935 non-null  object
#  8   away_ident      1237935 non-null  object
#  9   home_country    1237935 non-null  object
#  10  away_country    1237935 non-null  object
#  11  home_code       1237935 non-null  object
#  12  away_code       1237935 non-null  object
#  13  home_continent  1237935 non-null  object
#  14  away_continent  1237935 non-null  object
#  15  continent       1237935 non-null  object
#  16  level           1237935 non-null  object
# dtypes: int32(2), object(15)
# memory usage: 151.1+ MB
# None

# %%
print(df.describe())
# Out:
#                  gh            ga
# count  1.237935e+06  1.237935e+06
# mean   1.611417e+00  1.150681e+00
# std    1.443697e+00  1.216481e+00
# min    0.000000e+00  0.000000e+00
# 25%    1.000000e+00  0.000000e+00
# 50%    1.000000e+00  1.000000e+00
# 75%    2.000000e+00  2.000000e+00
# max    2.500000e+01  2.400000e+01

# %%
print(df.columns)
# Out:
# Index(['home', 'away', 'date', 'gh', 'ga', 'full_time', 'competition',
#        'home_ident', 'away_ident', 'home_country', 'away_country', 'home_code',
#        'away_code', 'home_continent', 'away_continent', 'continent', 'level'],
#       dtype='object')

# %%
# checking for missing values in each column
print(df.isnull().sum())
# Out:
# home               360
# away               367
# date                 0
# gh                   0
# ga                   0
# full_time            0
# competition       8502
# home_ident           0
# away_ident           0
# home_country         0
# away_country         0
# home_code            0
# away_code            0
# home_continent       0
# away_continent       0
# continent            0
# level                0
# dtype: int64

# %%
#  Drop rows with missing critical values
df = df.dropna(subset=['home', 'away', 'competition'])

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')
# Filter out all matches before January 1, 2000
df = df[df['date'] >= '2000-01-01']
print("Earliest date in dataset:", df['date'].min())
print(df[['date']].head())
# Out:
# Earliest date in dataset: 2000-01-01 00:00:00
#              date
# 468088 2000-01-01
# 468089 2000-01-01
# 468090 2000-01-01
# 468091 2000-01-01
# 468092 2000-01-01

# %%
# Check the unique values in the 'competition' column in order to drop non-europe competitions
unique_competitions = df['competition'].unique()
print("length of unique competitions in  dataset:", len(unique_competitions))

# Define the top five domestic league countries
top_leagues = ['england', 'spain', 'italy', 'germany', 'france']
uefa_comp = ['UEFA EL', 'UEFA CL', 'UEFA CONF L']


# condition to check for league matches
condition_domestic = df['competition'].str.lower().isin(top_leagues)

# condition to check for uefa competitions
condition_uefa = df['competition'].str.upper().isin(uefa_comp)

df_filtered = df[condition_domestic | condition_uefa]
df_filtered = df_filtered.sort_values(by='date')

# Print some information to verify filtering
print("Total matches before filtering:", len(df))
print("Total matches after filtering:", len(df_filtered))
print("Unique competitions in the filtered dataset:")
print(df_filtered['competition'].unique())
# Out:
# length of unique competitions in  dataset: 224
# Total matches before filtering: 765561
# Total matches after filtering: 58604
# Unique competitions in the filtered dataset:
# ['england' 'spain' 'italy' 'france' 'germany' 'UEFA EL' 'UEFA CL'
#  'UEFA CONF L']

# %%
df_filtered.tail()
# Out:
#                       home               away       date  gh  ga full_time  \
# 1237803         Luton Town         Chelsea FC 2023-12-30   2   3         F
# 1237808  Nottingham Forest  Manchester United 2023-12-30   2   1         F
# 1237827           Juventus            As Roma 2023-12-30   1   0         F
# 1237893          Fulham FC         Arsenal FC 2023-12-31   2   1         F
# 1237894  Tottenham Hotspur    Afc Bournemouth 2023-12-31   3   1         F
#
#         competition                   home_ident                   away_ident  \
# 1237803     england         Luton Town (England)         Chelsea FC (England)
# 1237808     england  Nottingham Forest (England)  Manchester United (England)
# 1237827       italy             Juventus (Italy)              As Roma (Italy)
# 1237893     england          Fulham FC (England)         Arsenal FC (England)
# 1237894     england  Tottenham Hotspur (England)    Afc Bournemouth (England)
#
#         home_country away_country home_code away_code home_continent  \
# 1237803      england      england       ENG       ENG         Europe
# 1237808      england      england       ENG       ENG         Europe
# 1237827        italy        italy        IT        IT         Europe
# 1237893      england      england       ENG       ENG         Europe
# 1237894      england      england       ENG       ENG         Europe
#
#         away_continent continent     level
# 1237803         Europe    Europe  national
# 1237808         Europe    Europe  national
# 1237827         Europe    Europe  national
# 1237893         Europe    Europe  national
# 1237894         Europe    Europe  national

# %% [markdown]
# ## Feature Engineering

# %%
def get_result(row):
    if row['gh'] > row['ga']:
        return 'home_win'
    elif row['gh'] < row['ga']:
        return 'away_win'
    else:
        return 'draw'

df_filtered['match_result'] = df_filtered.apply(get_result, axis=1)
df_filtered['goal_diff'] = df_filtered['gh'] - df_filtered['ga'] # tells the dominance of a team in a game. negatives in the direction of the opposing team
df_filtered['total_goals'] = df_filtered['gh'] + df_filtered['ga']

# %%
df_filtered.tail(10)
# Out:
#                             home               away       date  gh  ga  \
# 1237822                 Atalanta           US Lecce 2023-12-30   1   0
# 1237806          Manchester City   Sheffield United 2023-12-30   2   0
# 1237807  Wolverhampton Wanderers         Everton FC 2023-12-30   3   0
# 1237805           Crystal Palace       Brentford FC 2023-12-30   3   1
# 1237804              Aston Villa         Burnley FC 2023-12-30   3   2
# 1237803               Luton Town         Chelsea FC 2023-12-30   2   3
# 1237808        Nottingham Forest  Manchester United 2023-12-30   2   1
# 1237827                 Juventus            As Roma 2023-12-30   1   0
# 1237893                Fulham FC         Arsenal FC 2023-12-31   2   1
# 1237894        Tottenham Hotspur    Afc Bournemouth 2023-12-31   3   1
#
#         full_time competition                         home_ident  \
# 1237822         F       italy                   Atalanta (Italy)
# 1237806         F     england          Manchester City (England)
# 1237807         F     england  Wolverhampton Wanderers (England)
# 1237805         F     england           Crystal Palace (England)
# 1237804         F     england              Aston Villa (England)
# 1237803         F     england               Luton Town (England)
# 1237808         F     england        Nottingham Forest (England)
# 1237827         F       italy                   Juventus (Italy)
# 1237893         F     england                Fulham FC (England)
# 1237894         F     england        Tottenham Hotspur (England)
#
#                           away_ident home_country away_country home_code  \
# 1237822             US Lecce (Italy)        italy        italy        IT
# 1237806   Sheffield United (England)      england      england       ENG
# 1237807         Everton FC (England)      england      england       ENG
# 1237805       Brentford FC (England)      england      england       ENG
# 1237804         Burnley FC (England)      england      england       ENG
# 1237803         Chelsea FC (England)      england      england       ENG
# 1237808  Manchester United (England)      england      england       ENG
# 1237827              As Roma (Italy)        italy        italy        IT
# 1237893         Arsenal FC (England)      england      england       ENG
# 1237894    Afc Bournemouth (England)      england      england       ENG
#
#         away_code home_continent away_continent continent     level  \
# 1237822        IT         Europe         Europe    Europe  national
# 1237806       ENG         Europe         Europe    Europe  national
# 1237807       ENG         Europe         Europe    Europe  national
# 1237805       ENG         Europe         Europe    Europe  national
# 1237804       ENG         Europe         Europe    Europe  national
# 1237803       ENG         Europe         Europe    Europe  national
# 1237808       ENG         Europe         Europe    Europe  national
# 1237827        IT         Europe         Europe    Europe  national
# 1237893       ENG         Europe         Europe    Europe  national
# 1237894       ENG         Europe         Europe    Europe  national
#
#         match_result  goal_diff  total_goals
# 1237822     home_win          1            1
# 1237806     home_win          2            2
# 1237807     home_win          3            3
# 1237805     home_win          2            4
# 1237804     home_win          1            5
# 1237803     away_win         -1            5
# 1237808     home_win          1            3
# 1237827     home_win          1            1
# 1237893     home_win          1            3
# 1237894     home_win          2            4

# %% [markdown]
# #### Creating Season Identifier plus determining rest days for each team

# %%
# Extract year, month, and day of week from the date
df_filtered['year'] = df_filtered['date'].dt.year
df_filtered['month'] = df_filtered['date'].dt.month
df_filtered['day_of_week'] = df_filtered['date'].dt.dayofweek  # 0=Monday, 6=Sunday

print(df_filtered[['date', 'year', 'month', 'day_of_week']].head())
# Out:
#              date  year  month  day_of_week
# 468120 2000-01-03  2000      1            0
# 468121 2000-01-03  2000      1            0
# 468122 2000-01-03  2000      1            0
# 468123 2000-01-03  2000      1            0
# 468124 2000-01-03  2000      1            0

# %%
# since I am using europe's standard for a season. I will probably drop other leagues from the data set and focus on europe football
def get_season(row):
    year = row['year']
    month = row['month']
    # Adjust the cutoff as needed; here we assume season starts in August
    if month >= 8:
        season_start = year
        season_end = year + 1
    else:
        season_start = year - 1
        season_end = year
    return f"{season_start}-{season_end}"

# Create a new 'season' column using the helper function
df_filtered['season'] = df_filtered.apply(get_season, axis=1)

# Check the results
print(df_filtered[['date', 'year', 'month', 'season']].tail(10))
# Out:
#               date  year  month     season
# 1237822 2023-12-30  2023     12  2023-2024
# 1237806 2023-12-30  2023     12  2023-2024
# 1237807 2023-12-30  2023     12  2023-2024
# 1237805 2023-12-30  2023     12  2023-2024
# 1237804 2023-12-30  2023     12  2023-2024
# 1237803 2023-12-30  2023     12  2023-2024
# 1237808 2023-12-30  2023     12  2023-2024
# 1237827 2023-12-30  2023     12  2023-2024
# 1237893 2023-12-31  2023     12  2023-2024
# 1237894 2023-12-31  2023     12  2023-2024

# %%
# Calculating rest days.


# For home teams: calculate days since the previous home match for each home team
df_filtered['home_rest_days'] = df_filtered.groupby('home_ident')['date'].diff().dt.days

# For away teams: calculate days since the previous away match for each away team
df_filtered['away_rest_days'] = df_filtered.groupby('away_ident')['date'].diff().dt.days

# Inspect the new rest day columns
print(df_filtered[['home', 'date', 'home_rest_days']].tail(10))
print(df_filtered[['away', 'date', 'away_rest_days']].tail(10))
# Out:
#                             home       date  home_rest_days
# 1237822                 Atalanta 2023-12-30            12.0
# 1237806          Manchester City 2023-12-30            14.0
# 1237807  Wolverhampton Wanderers 2023-12-30             6.0
# 1237805           Crystal Palace 2023-12-30             9.0
# 1237804              Aston Villa 2023-12-30             8.0
# 1237803               Luton Town 2023-12-30             7.0
# 1237808        Nottingham Forest 2023-12-30             7.0
# 1237827                 Juventus 2023-12-30            22.0
# 1237893                Fulham FC 2023-12-31             8.0
# 1237894        Tottenham Hotspur 2023-12-31             8.0
#                       away       date  away_rest_days
# 1237822           US Lecce 2023-12-30             7.0
# 1237806   Sheffield United 2023-12-30             8.0
# 1237807         Everton FC 2023-12-30             7.0
# 1237805       Brentford FC 2023-12-30            21.0
# 1237804         Burnley FC 2023-12-30             7.0
# 1237803         Chelsea FC 2023-12-30             6.0
# 1237808  Manchester United 2023-12-30             7.0
# 1237827            As Roma 2023-12-30            13.0
# 1237893         Arsenal FC 2023-12-31             8.0
# 1237894    Afc Bournemouth 2023-12-31             8.0

# %%
df_filtered.tail()
# Out:
#                       home               away       date  gh  ga full_time  \
# 1237803         Luton Town         Chelsea FC 2023-12-30   2   3         F
# 1237808  Nottingham Forest  Manchester United 2023-12-30   2   1         F
# 1237827           Juventus            As Roma 2023-12-30   1   0         F
# 1237893          Fulham FC         Arsenal FC 2023-12-31   2   1         F
# 1237894  Tottenham Hotspur    Afc Bournemouth 2023-12-31   3   1         F
#
#         competition                   home_ident                   away_ident  \
# 1237803     england         Luton Town (England)         Chelsea FC (England)
# 1237808     england  Nottingham Forest (England)  Manchester United (England)
# 1237827       italy             Juventus (Italy)              As Roma (Italy)
# 1237893     england          Fulham FC (England)         Arsenal FC (England)
# 1237894     england  Tottenham Hotspur (England)    Afc Bournemouth (England)
#
#         home_country  ...     level match_result goal_diff total_goals  year  \
# 1237803      england  ...  national     away_win        -1           5  2023
# 1237808      england  ...  national     home_win         1           3  2023
# 1237827        italy  ...  national     home_win         1           1  2023
# 1237893      england  ...  national     home_win         1           3  2023
# 1237894      england  ...  national     home_win         2           4  2023
#
#         month day_of_week     season  home_rest_days  away_rest_days
# 1237803    12           5  2023-2024             7.0             6.0
# 1237808    12           5  2023-2024             7.0             7.0
# 1237827    12           5  2023-2024            22.0            13.0
# 1237893    12           6  2023-2024             8.0             8.0
# 1237894    12           6  2023-2024             8.0             8.0
#
# [5 rows x 26 columns]

# %% [markdown]
# Seperating national from international level

# %%
# competition encoding
df_encoded = pd.get_dummies(df_filtered, columns=['competition'], prefix='comp')

# level of competition
df_encoded = pd.get_dummies(df_encoded, columns=['level'], prefix='level')

# domestic vs international
# Create a binary feature: 1 if the match is domestic (i.e., home_country equals away_country), 0 if international.
df_encoded['domestic'] = (df_encoded['home_country'] == df_encoded['away_country']).astype(int)

# One-hot encode the home and away continents.
df_encoded = pd.get_dummies(df_encoded, columns=['home_continent'], prefix='home_cont')
df_encoded = pd.get_dummies(df_encoded, columns=['away_continent'], prefix='away_cont')



print(df_encoded.sample(n=10))
# Out:
#                        home                          away       date  gh  ga  \
# 1009299     1899 Hoffenheim                 Werder Bremen 2017-08-19   1   0
# 871934         Cardiff City                  Swansea City 2013-11-03   1   0
# 755648         Hajduk Split  FC Unirea Valahorum Urziceni 2010-08-19   4   1
# 536276   Girondins Bordeaux                    FC Sochaux 2003-03-01   2   0
# 556900           Bologna FC                 Ancona Calcio 2003-12-07   3   2
# 620348       Wigan Athletic                   Aston Villa 2006-04-18   3   2
# 1221323          Kuopion Ps                    Derry City 2023-08-03   3   3
# 784712           Levante Ud                 Real Zaragoza 2011-05-21   1   2
# 1199589            US Lecce                      AC Milan 2023-01-14   2   2
# 526075           Leixoes SC                 Paok Saloniki 2002-09-19   2   1
#
#         full_time                   home_ident  \
# 1009299         F    1899 Hoffenheim (Germany)
# 871934          F         Cardiff City (Wales)
# 755648          F       Hajduk Split (Croatia)
# 536276          F  Girondins Bordeaux (France)
# 556900          F           Bologna FC (Italy)
# 620348          F     Wigan Athletic (England)
# 1221323         F         Kuopion Ps (Finland)
# 784712          F           Levante Ud (Spain)
# 1199589         F             US Lecce (Italy)
# 526075          F        Leixoes SC (Portugal)
#
#                                      away_ident home_country  \
# 1009299                 Werder Bremen (Germany)      germany
# 871934                     Swansea City (Wales)        wales
# 755648   FC Unirea Valahorum Urziceni (Romania)      croatia
# 536276                      FC Sochaux (France)       france
# 556900                    Ancona Calcio (Italy)        italy
# 620348                    Aston Villa (England)      england
# 1221323           Derry City (Northern Ireland)      finland
# 784712                    Real Zaragoza (Spain)        spain
# 1199589                        AC Milan (Italy)        italy
# 526075                   Paok Saloniki (Greece)     portugal
#
#              away_country  ... comp_england comp_france comp_germany  \
# 1009299           germany  ...        False       False         True
# 871934              wales  ...         True       False        False
# 755648            romania  ...        False       False        False
# 536276             france  ...        False        True        False
# 556900              italy  ...        False       False        False
# 620348            england  ...         True       False        False
# 1221323  northern-ireland  ...        False       False        False
# 784712              spain  ...        False       False        False
# 1199589             italy  ...        False       False        False
# 526075             greece  ...        False       False        False
#
#         comp_italy  comp_spain  level_international  level_national  domestic  \
# 1009299      False       False                False            True         1
# 871934       False       False                False            True         1
# 755648       False       False                 True           False         0
# 536276       False       False                False            True         1
# 556900        True       False                False            True         1
# 620348       False       False                False            True         1
# 1221323      False       False                 True           False         0
# 784712       False        True                False            True         1
# 1199589       True       False                False            True         1
# 526075       False       False                 True           False         0
#
#          home_cont_Europe away_cont_Europe
# 1009299              True             True
# 871934               True             True
# 755648               True             True
# 536276               True             True
# 556900               True             True
# 620348               True             True
# 1221323              True             True
# 784712               True             True
# 1199589              True             True
# 526075               True             True
#
# [10 rows x 35 columns]

# %%
# copy of df_filtered
df_perf = df_filtered.copy()
# I have like four data frames now lol

# Calculating momentum
window_size = 5

### 1. Rolling Averages (Recent Form) – Updated to avoid leakage

# For home teams: rolling average of goals scored, using only historical matches.
df_perf = df_perf.sort_values(['home_ident', 'date'])
df_perf.loc[:, 'home_avg_goals_scored'] = df_perf.groupby('home_ident')['gh'].transform(
    lambda x: x.shift(1).rolling(window=window_size, min_periods=1).mean()
)

# For home teams: rolling average of goals conceded (ga), using only historical matches.
df_perf.loc[:, 'home_avg_goals_conceded'] = df_perf.groupby('home_ident')['ga'] \
    .transform(lambda x: x.shift(1).rolling(window=window_size, min_periods=1).mean())

# For away teams: rolling average of goals scored (ga) for away teams.
df_perf.loc[:, 'away_avg_goals_scored'] = df_perf.groupby('away_ident')['ga'] \
    .transform(lambda x: x.shift(1).rolling(window=window_size, min_periods=1).mean())

# For away teams: rolling average of goals conceded (gh) for away teams.
df_perf = df_perf.sort_values(['away_ident', 'date'])
df_perf.loc[:, 'away_avg_goals_scored'] = df_perf.groupby('away_ident')['ga'].transform(
    lambda x: x.shift(1).rolling(window=window_size, min_periods=1).mean()
)
df_perf.loc[:, 'away_avg_goals_conceded'] = df_perf.groupby('away_ident')['gh'].transform(
    lambda x: x.shift(1).rolling(window=window_size, min_periods=1).mean()
)


# b) Rolling Win Rate Calculation
# Create binary indicators for wins.
df_perf.loc[:, 'home_win_indicator'] = (df_perf['match_result'] == 'home_win').astype(int)
df_perf.loc[:, 'away_win_indicator'] = (df_perf['match_result'] == 'away_win').astype(int)

# Compute rolling win rates using shift to ensure only past matches are used.
df_perf.loc[:, 'home_win_rate'] = df_perf.groupby('home_ident')['home_win_indicator'].transform(
    lambda x: x.shift(1).rolling(window=window_size, min_periods=1).mean()
)
df_perf.loc[:, 'away_win_rate'] = df_perf.groupby('away_ident')['away_win_indicator'].transform(
    lambda x: x.shift(1).rolling(window=window_size, min_periods=1).mean()
)

### 2. Head-to-Head Records

# Sort by date to ensure chronological order for head-to-head features
df_perf.sort_values('date', inplace=True)
df_perf.loc[:, 'cumulative_home_wins'] = df_perf.groupby(['home_ident', 'away_ident'])['home_win_indicator'].cumsum()
df_perf.loc[:, 'head2head_home_wins'] = df_perf.groupby(['home_ident', 'away_ident'])['cumulative_home_wins'].shift(1)
df_perf.loc[:, 'head2head_home_wins'] = df_perf['head2head_home_wins'].fillna(0).astype(int)
df_perf.loc[:, 'head2head_total_matches'] = df_perf.groupby(['home_ident', 'away_ident'])['home'].cumcount()
df_perf.loc[:, 'head2head_win_ratio'] = df_perf.apply(
    lambda row: row['head2head_home_wins'] / row['head2head_total_matches'] if row['head2head_total_matches'] > 0 else 0, axis=1
)

### Inspect a sample of head-to-head and rolling features
print(df_perf[['date', 'home', 'away', 'gh', 'ga', 
               'home_avg_goals_scored', 'home_avg_goals_conceded',
               'away_avg_goals_scored', 'away_avg_goals_conceded',
               'home_win_rate', 'away_win_rate',
               'head2head_home_wins', 'head2head_total_matches', 'head2head_win_ratio']].tail(10))
# Out:
#               date                     home               away  gh  ga  \
# 1237822 2023-12-30                 Atalanta           US Lecce   1   0
# 1237805 2023-12-30           Crystal Palace       Brentford FC   3   1
# 1237807 2023-12-30  Wolverhampton Wanderers         Everton FC   3   0
# 1237808 2023-12-30        Nottingham Forest  Manchester United   2   1
# 1237823 2023-12-30          Cagliari Calcio          Empoli FC   0   0
# 1237806 2023-12-30          Manchester City   Sheffield United   2   0
# 1237826 2023-12-30                 AC Milan    Sassuolo Calcio   1   0
# 1237803 2023-12-30               Luton Town         Chelsea FC   2   3
# 1237894 2023-12-31        Tottenham Hotspur    Afc Bournemouth   3   1
# 1237893 2023-12-31                Fulham FC         Arsenal FC   2   1
#
#          home_avg_goals_scored  home_avg_goals_conceded  \
# 1237822                    2.0                      1.2
# 1237805                    1.0                      2.0
# 1237807                    1.6                      1.0
# 1237808                    1.2                      1.8
# 1237823                    2.0                      2.0
# 1237806                    2.4                      1.6
# 1237826                    2.0                      1.0
# 1237803                    1.6                      1.6
# 1237894                    1.8                      2.0
# 1237893                    2.6                      1.0
#
#          away_avg_goals_scored  away_avg_goals_conceded  home_win_rate  \
# 1237822                    1.0                      1.6            0.2
# 1237805                    0.8                      1.6            0.2
# 1237807                    1.6                      0.8            0.4
# 1237808                    1.2                      1.2            0.4
# 1237823                    1.0                      0.8            0.4
# 1237806                    0.4                      2.8            0.6
# 1237826                    1.8                      2.0            0.2
# 1237803                    1.4                      2.2            0.0
# 1237894                    2.4                      1.8            0.8
# 1237893                    1.4                      1.2            0.0
#
#          away_win_rate  head2head_home_wins  head2head_total_matches  \
# 1237822            0.0                  3.0                        7
# 1237805            0.2                  0.0                        2
# 1237807            0.8                  3.0                        9
# 1237808            0.2                  0.0                        1
# 1237823            0.4                  3.0                        7
# 1237806            0.0                  2.0                        3
# 1237826            0.2                  4.0                       10
# 1237803            0.2                  0.0                        0
# 1237894            0.8                  5.0                        6
# 1237893            0.4                  3.0                       16
#
#          head2head_win_ratio
# 1237822             0.428571
# 1237805             0.000000
# 1237807             0.333333
# 1237808             0.000000
# 1237823             0.428571
# 1237806             0.666667
# 1237826             0.400000
# 1237803             0.000000
# 1237894             0.833333
# 1237893             0.187500

# %%
### MORE ON ROLLING FORM

# Differential and Interaction Features
df_perf.loc[:, 'rolling_goal_diff'] = df_perf['home_avg_goals_scored'] - df_perf['away_avg_goals_conceded']
df_perf.loc[:, 'win_rate_diff'] = df_perf['home_win_rate'] - df_perf['away_win_rate']

df_perf.loc[:, 'home_rest_x_win_rate'] = df_perf['home_rest_days'] * df_perf['home_win_rate']
df_perf.loc[:, 'away_rest_x_win_rate'] = df_perf['away_rest_days'] * df_perf['away_win_rate']

print(df_perf[['date', 'home', 'away', 
               'home_avg_goals_scored', 'away_avg_goals_conceded', 'rolling_goal_diff',
               'home_win_rate', 'away_win_rate', 'win_rate_diff',
               'home_rest_days', 'home_rest_x_win_rate',
               'away_rest_days', 'away_rest_x_win_rate']].tail(10))
# Out:
#               date                     home               away  \
# 1237822 2023-12-30                 Atalanta           US Lecce
# 1237805 2023-12-30           Crystal Palace       Brentford FC
# 1237807 2023-12-30  Wolverhampton Wanderers         Everton FC
# 1237808 2023-12-30        Nottingham Forest  Manchester United
# 1237823 2023-12-30          Cagliari Calcio          Empoli FC
# 1237806 2023-12-30          Manchester City   Sheffield United
# 1237826 2023-12-30                 AC Milan    Sassuolo Calcio
# 1237803 2023-12-30               Luton Town         Chelsea FC
# 1237894 2023-12-31        Tottenham Hotspur    Afc Bournemouth
# 1237893 2023-12-31                Fulham FC         Arsenal FC
#
#          home_avg_goals_scored  away_avg_goals_conceded  rolling_goal_diff  \
# 1237822                    2.0                      1.6                0.4
# 1237805                    1.0                      1.6               -0.6
# 1237807                    1.6                      0.8                0.8
# 1237808                    1.2                      1.2                0.0
# 1237823                    2.0                      0.8                1.2
# 1237806                    2.4                      2.8               -0.4
# 1237826                    2.0                      2.0                0.0
# 1237803                    1.6                      2.2               -0.6
# 1237894                    1.8                      1.8                0.0
# 1237893                    2.6                      1.2                1.4
#
#          home_win_rate  away_win_rate  win_rate_diff  home_rest_days  \
# 1237822            0.2            0.0            0.2            12.0
# 1237805            0.2            0.2            0.0             9.0
# 1237807            0.4            0.8           -0.4             6.0
# 1237808            0.4            0.2            0.2             7.0
# 1237823            0.4            0.4            0.0            19.0
# 1237806            0.6            0.0            0.6            14.0
# 1237826            0.2            0.2            0.0            13.0
# 1237803            0.0            0.2           -0.2             7.0
# 1237894            0.8            0.8            0.0             8.0
# 1237893            0.0            0.4           -0.4             8.0
#
#          home_rest_x_win_rate  away_rest_days  away_rest_x_win_rate
# 1237822                   2.4             7.0                   0.0
# 1237805                   1.8            21.0                   4.2
# 1237807                   2.4             7.0                   5.6
# 1237808                   2.8             7.0                   1.4
# 1237823                   7.6            14.0                   5.6
# 1237806                   8.4             8.0                   0.0
# 1237826                   2.6            13.0                   2.6
# 1237803                   0.0             6.0                   1.2
# 1237894                   6.4             8.0                   6.4
# 1237893                   0.0             8.0                   3.2

# %%
# Merging the dataframes
cols_to_merge = [col for col in df_encoded.columns if col not in df_perf.columns]
final_df = pd.concat([df_perf, df_encoded[cols_to_merge]], axis=1)
print(final_df.head())
# Out:
#                      home            away       date  gh  ga full_time  \
# 468127     Southampton FC   Bradford City 2000-01-03   1   0         F
# 468123         Everton FC  Leicester City 2000-01-03   2   2         F
# 468121  Tottenham Hotspur    Liverpool FC 2000-01-03   1   0         F
# 468122       Leeds United     Aston Villa 2000-01-03   1   2         F
# 468124      Afc Wimbledon  Sunderland Afc 2000-01-03   1   0         F
#
#        competition                   home_ident                away_ident  \
# 468127     england     Southampton FC (England)   Bradford City (England)
# 468123     england         Everton FC (England)  Leicester City (England)
# 468121     england  Tottenham Hotspur (England)    Liverpool FC (England)
# 468122     england       Leeds United (England)     Aston Villa (England)
# 468124     england      Afc Wimbledon (England)  Sunderland Afc (England)
#
#        home_country  ... comp_england comp_france comp_germany comp_italy  \
# 468127      england  ...         True       False        False      False
# 468123      england  ...         True       False        False      False
# 468121      england  ...         True       False        False      False
# 468122      england  ...         True       False        False      False
# 468124      england  ...         True       False        False      False
#
#        comp_spain level_international level_national domestic  \
# 468127      False               False           True        1
# 468123      False               False           True        1
# 468121      False               False           True        1
# 468122      False               False           True        1
# 468124      False               False           True        1
#
#         home_cont_Europe  away_cont_Europe
# 468127              True              True
# 468123              True              True
# 468121              True              True
# 468122              True              True
# 468124              True              True
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Preprocessing the features

# %%
final_df = pd.get_dummies(final_df, columns=['season'], prefix='season')
final_df = final_df.sort_values('date')
print(final_df.isnull().sum())
# dropping rows with any missing values
final_df = final_df.dropna()

# Split into training (80%) and test sets by date
cutoff_date = final_df['date'].quantile(0.8)
train_df = final_df[final_df['date'] <= cutoff_date]
test_df = final_df[final_df['date'] > cutoff_date]

print("Training set size:", len(train_df))
print("Test set size:", len(test_df))

# Define target variable and drop leak-prone columns
y_train = train_df['match_result']
y_test = test_df['match_result']
features_to_drop = ['date', 'match_result', 'home', 'away', 'home_ident', 'away_ident', 'gh', 'ga', 'goal_diff', 'total_goals']
X_train = train_df.drop(columns=features_to_drop)
X_test = test_df.drop(columns=features_to_drop)
# Out:
# home                0
# away                0
# date                0
# gh                  0
# ga                  0
#                    ..
# season_2019-2020    0
# season_2020-2021    0
# season_2021-2022    0
# season_2022-2023    0
# season_2023-2024    0
# Length: 79, dtype: int64
# Training set size: 45035
# Test set size: 11255

# %% [markdown]
# ##### Preprocessing with Column Transformer

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

numeric_features = X_train.select_dtypes(include=['int64', 'float64', 'int32']).columns.tolist()
categorical_features = X_train.select_dtypes(include=['object', 'category']).columns.tolist()

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ]
)

X_train_preprocessed = preprocessor.fit_transform(X_train)
X_test_preprocessed = preprocessor.transform(X_test)

# %% [markdown]
# ##### Model Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

model = LogisticRegression(multi_class='multinomial', max_iter=1000, solver='lbfgs')
model.fit(X_train_preprocessed, y_train)

y_pred = model.predict(X_test_preprocessed)
y_proba = model.predict_proba(X_test_preprocessed)

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[3521    0    0]
#  [   0 2699    0]
#  [   0    0 5035]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     away_win       1.00      1.00      1.00      3521
#         draw       1.00      1.00      1.00      2699
#     home_win       1.00      1.00      1.00      5035
#
#     accuracy                           1.00     11255
#    macro avg       1.00      1.00      1.00     11255
# weighted avg       1.00      1.00      1.00     11255
# /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(

# %%
from sklearn.calibration import calibration_curve
# %pip install matplotlib
import matplotlib.pyplot as plt
import numpy as np

home_win_index = np.where(model.classes_ == 'home_win')[0][0]
prob_true, prob_pred = calibration_curve((y_test == 'home_win').astype(int), 
                                           y_proba[:, home_win_index],
                                           n_bins=10)

plt.figure(figsize=(8,6))
plt.plot(prob_pred, prob_true, marker='o', linewidth=1, label='Home Win')
plt.plot([0, 1], [0, 1], linestyle='--', label='Perfect Calibration')
plt.xlabel('Mean Predicted Probability')
plt.ylabel('Fraction of Positives')
plt.title('Calibration Plot for Home Win')
plt.legend()
plt.show()
#hello
# Out:
# Requirement already satisfied: matplotlib in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/emmanuel/Documents/haclytics/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
